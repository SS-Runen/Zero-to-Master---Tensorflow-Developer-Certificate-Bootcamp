# %% [markdown]
# # Zero to Mastery - TensorFlow Developer Certificate Bootcamp

# %% [markdown]
# https://github.com/mrdbourke/tensorflow-deep-learning
#
# https://dev.mrdbourke.com/tensorflow-deep-learning/
#
# https://www.udemy.com/course/tensorflow-developer-certificate-machine-learning-zero-to-mastery/?couponCode=KEEPLEARNING

# %% [markdown]
# # Tensor Basics

# %%
import tensorflow as tf
import numpy as np
# Out:
# 2024-05-03 15:07:27.153606: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-03 15:07:27.153696: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-03 15:07:27.242052: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-03 15:07:27.408954: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# #### 18. Creating random tensors with TensorFlow

# %%
random_tensor_generator = tf.random.Generator.from_seed(0)
print(random_tensor_generator)

# %%
random_tensor_generator.normal(shape=(2,16))
# Out:
# <tf.Tensor: shape=(2, 16), dtype=float32, numpy=
# array([[-1.0336804 , -0.69517773,  0.3495093 ,  1.2831469 , -0.4911447 ,
#          0.71773195,  0.09561951,  1.2891091 ,  0.17518568, -1.1813893 ,
#          0.29794395, -0.7486929 ,  0.14882371,  0.4140094 , -0.11358494,
#         -1.6858402 ],
#        [ 0.95915365, -0.23748821,  0.8942145 , -0.22224665,  1.1621152 ,
#         -0.2670094 ,  0.7058913 , -0.07967272, -0.13365039, -0.48810783,
#         -0.28434843,  1.0522115 ,  1.2435325 ,  0.49984065,  1.7441503 ,
#         -0.25176144]], dtype=float32)>

# %%
random_tensor_generator.uniform(shape=(2,16))
# Out:
# <tf.Tensor: shape=(2, 16), dtype=float32, numpy=
# array([[0.7582407 , 0.9499773 , 0.33463418, 0.7377672 , 0.47967136,
#         0.9780489 , 0.05419588, 0.4630406 , 0.595278  , 0.36960614,
#         0.77548385, 0.25091922, 0.20719576, 0.38242626, 0.27619958,
#         0.9393983 ],
#        [0.24518633, 0.09289575, 0.19967258, 0.10018313, 0.2778405 ,
#         0.48602998, 0.6679785 , 0.40757263, 0.10717809, 0.36692345,
#         0.556224  , 0.48590326, 0.20424843, 0.58619297, 0.9977828 ,
#         0.6185322 ]], dtype=float32)>

# %% [markdown]
# #### 22. Indexing and Expanding Tensors

# %% [markdown]
# Access elements in different dimensions.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Add a dimension to a certain axis using tf.newaxis
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Add a dimension using tf.expand_dims
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 24. Matrix multiplication with tensors
#
# Step-by-step Visualization:
# http://matrixmultiplication.xyz/

# %% [markdown]
# tf.transpose vs. tf.reshape
#
# ![image.png](attachment:image.png)
#
# Transpose performs the proper mathematical switching of rows and columns. Reshape fits the elements to the specified shape without obeying the rules of matrices.

# %% [markdown]
# Use tf.cast to change the Tensor element data type.
#
# ![image.png](attachment:image.png)
#
# If the integers are guaranteed to fit lower-precision data types, cast them to increase processing speed.

# %% [markdown]
# #### Tensor Aggregation

# %% [markdown]
# If the function requires a complex data type, use types like tf.float32, not basic types like tf.int.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Use tf.argmax or np.argmax to find the maximum value along an axis. This will give the positional index of the maximum value. If the output is a matrix with columns line up with different classes and rows of output per example, the number you get is the positional index of the class with the highest corresponding value for each row.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# tf.squeeze removes all single-dimensions from the tensor. It retains the elements.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Check what GPUs TensorFlow can access. This list will show CPUs and GPUs detected by TensorFlow.
#
# `tf.config.list_physical_devices`

# %%
tf.config.list_physical_devices()
# Out:
# 2024-05-03 15:07:35.907925: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-03 15:07:36.157411: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %% [markdown]
# To run terminal commands in a Jupyter Notebook cell, add the "!" character before a line. Code has to be written line by line. One exclamation mak per line.

# %%
# !nvidia-smi
# Out:
# Fri May  3 15:09:25 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1050 Ti     Off |   00000000:0A:00.0  On |                  N/A |
# |  0%   43C    P8             N/A /   72W |     223MiB /   4096MiB |     19%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# Colab Docstrings
#
# In Google Colab, you can command to display the docstring using Ctrl + Shift + Space.

# %% [markdown]
# # Neural Network Regression with TensorFlow

# %% [markdown]
# ## Visualizing and Evaluating Models

# %% [markdown]
# To generate a picture of a model, import `from tensorflow.keras.utils import plot_model`

# %% [markdown]
# Use `plt.figure` to create a plot object. The object can be manipulated and re-used with different data or additional data throughout the notebook.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# To explicitly evaluate a model's predictions, use `tf.Model.evaluate` from the model object. This step is usually done on the test set. When training the model, cross-validation data may be passed to the `validate` parameter. After the best models and hyper-parameters are picked, they have to be evaluated on the test data.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# A custom loss function can be defined as a method or as a class.
#
# ![image.png](attachment:image.png)
#
# Compile with this loss function using
#
# `model.compile(optimizer=tf.optimizers.SGD(), loss=contrastive_loss(0.5))`

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Compile with this loss function class using
#
# `model.compile(optimizer=tf.optimizers.SGD(), loss=ConstrastiveLoss(0))`

# %% [markdown]
# Loss functions or classes can be called without being passed to a model object.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Sample common error evaluation functions.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 56. Setting up TensorFlow modelling experiments part 1 (start with a simple model)
